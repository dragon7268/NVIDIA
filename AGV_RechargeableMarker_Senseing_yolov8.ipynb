# %% [markdown]
# <a href="https://colab.research.google.com/github/dragon7268/NVIDIA/blob/AGV_RechargeableMarker_Senseing/AGV_RechargeableMarker_Senseing_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 878.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import files
uploaded = files.upload()  # 여기서 ZIP 파일 올려
# Out:
#      <input type="file" id="files-323aa81a-a864-493a-a084-9dc630451580" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-323aa81a-a864-493a-a084-9dc630451580">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "AGV_RechargeableMarker_Senseing.v1i.yolov8.zip"  # ZIP 파일명에 맞게 수정
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("dataset")  # 원하는 경로로 압축 해제

# 해제된 파일 구조 확인
os.listdir("dataset")
# Out:
# ['data.yaml', 'train', 'README.roboflow.txt', 'README.dataset.txt']

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # 또는 yolov8s.pt 등
model.train(data='/content/dataset/data.yaml', epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train2/weights/best.pt')

# 테스트 이미지 폴더에 대해 추론
results = model('/content/dataset/train/images', save=True)  # 자동 저장
# Out:
# image 1/300 /content/dataset/train/images/100000000_png.rf.772455f21224bb6544c338e10f60cb86.jpg: 640x640 4 marks, 8.0ms
# image 2/300 /content/dataset/train/images/100000001_png.rf.3e9d0f184db1333a8fa411f2e772b9c6.jpg: 640x640 4 marks, 12.4ms
# image 3/300 /content/dataset/train/images/100000006_png.rf.58de57b44edd55d78ec70c48defeecff.jpg: 640x640 4 marks, 10.8ms
# image 4/300 /content/dataset/train/images/100000020_png.rf.5b31da8e20f07c72f54bd444cbe51748.jpg: 640x640 4 marks, 7.7ms
# image 5/300 /content/dataset/train/images/100000025_png.rf.e7d3336ac2ac50e7d89575ba4968b2f1.jpg: 640x640 4 marks, 7.3ms
# image 6/300 /content/dataset/train/images/100000028_png.rf.38fd00cd1d45b2f9856706f4c9b0fac8.jpg: 640x640 4 marks, 7.3ms
# image 7/300 /content/dataset/train/images/100000029_png.rf.b3797f22653e21fb083fff9e483c7028.jpg: 640x640 4 marks, 7.4ms
# image 8/300 /content/dataset/train/images/100000030_png.rf.ee2fba65b650dbb86cc722b1a15de7e7.jpg: 640x640 4 marks, 7.3ms
# ...

# %%
import cv2
import os
from glob import glob

# 추론 결과 이미지들이 저장된 폴더
img_folder = '/content/runs/detect/predict'
output_video = '/content/prediction_result.mp4'

# 이미지 파일 목록 불러오기 및 정렬
img_files = sorted(glob(os.path.join(img_folder, '*.jpg')))

# 첫 이미지로 크기 가져오기
frame = cv2.imread(img_files[0])
height, width, _ = frame.shape

# 비디오 설정 (FPS: 5, 코덱: mp4v)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(output_video, fourcc, 5, (width, height))

# 이미지들을 비디오로 저장
for img_file in img_files:
    frame = cv2.imread(img_file)
    video.write(frame)

video.release()
print("✅ 비디오 생성 완료:", output_video)
# Out:
# ✅ 비디오 생성 완료: /content/prediction_result.mp4

# %%
from google.colab import files
files.download(output_video)
